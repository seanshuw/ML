# %%
import keras
from keras.layers import Input, Dense, Flatten, Conv1D, LSTM, Dropout
from keras.models import load_model, Model
from sklearn.metrics import roc_curve, auc
import numpy as np
import os
import h5py
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.regularizers import l1
from collections import namedtuple
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from train import parse_config, get_features

Option = namedtuple("MyStruct", "inputModel inputFile tree config outputDir ")
options = Option(
    inputModel = 'KERAS_conv1d_weights.h5',
    inputFile = 'processed-pythia82-lhc13-all-pt1-50k-r1_h022_e0175_t220_nonu_withPars_truth_0.z',
    tree = 't_allpar_new',
    config = 'train_config_conv1d.yml',
    outputDir = 'output'
)

print("Loading configuration from", options.config)
config = open(options.config, 'r')
yamlConfig =  yaml.load(config, Loader = yaml.FullLoader)
yamlConfig
# Out:
# Using TensorFlow backend.
# Loading configuration from train_config_conv1d.yml
# {'Inputs': ['j1_ptrel',
#   'j1_etarot',
#   'j1_phirot',
#   'j1_erel',
#   'j1_deltaR',
#   'j1_costhetarel',
#   'j1_pdgid',
#   'j_index'],
#  'Labels': ['j_g', 'j_q', 'j_w', 'j_z', 'j_t', 'j_index'],
#  'KerasModel': 'conv1d_model',
#  'KerasModelRetrain': 'conv1d_model_constraint',
#  'KerasLoss': 'categorical_crossentropy',
#  'L1Reg': 0.0001,
#  'NormalizeInputs': 1,
#  'InputType': 'Conv1D',
#  'MaxParticles': 100}

# %%
f = h5py.File(options.inputFile, 'r')
treeArray = f[options.tree][()]
#features = ['j1_ptrel','j1_etarot','j1_phirot','j1_erel','j1_deltaR','j1_costhetarel','j1_pdgid','j1_pt']
#labels = ['j_g','j_q','j_w','j_z','j_t']

features = yamlConfig['Inputs']
labels = yamlConfig['Labels']

features_df = pd.DataFrame(treeArray,columns=list(set(features)))
labels_df = pd.DataFrame(treeArray,columns=list(set(labels)))

features_labels_df = pd.DataFrame(treeArray,columns = list(set(features + labels)))
features_labels_df = features_labels_df.drop_duplicates()

features_labels_df
# Out:
#          j1_deltaR  j1_costhetarel  j_g   j1_erel  j_q  j1_ptrel  j_z  \
# 0         0.011056    6.123234e-17    1  0.382772    0  0.386118    0
# 1         0.023104   -9.858313e-03    1  0.105703    0  0.107734    0
# 2         0.006306    4.508108e-03    1  0.094339    0  0.094731    0
# 3         0.022473    2.855927e-02    1  0.042913    0  0.042086    0
# 4         0.025492   -1.801822e-02    1  0.038547    0  0.039412    0
# ...            ...             ...  ...       ...  ...       ...  ...
# 5131608   0.380018   -2.917658e-01    0  0.000344    0  0.000350    1
# 5131609   0.294476    2.532998e-01    0  0.000256    0  0.000258    1
# 5131610   0.255231    2.628331e-01    0  0.000215    0  0.000219    1
# 5131611   0.319973   -2.099133e-01    0  0.000115    0  0.000116    1
# 5131612   0.395627    3.940748e-01    0  0.000079    0  0.000080    1
#
#          j1_etarot  j_w  j_t    j_index  j1_pdgid  j1_phirot
# 0         0.000000    0    0     101333     130.0   0.000000
# 1        -0.009859    0    0     101333     211.0   0.007236
# 2         0.004508    0    0     101333     321.0  -0.002759
# 3         0.028567    0    0     101333     211.0  -0.014909
# 4        -0.018020    0    0     101333    -211.0  -0.003745
# ...            ...  ...  ...        ...       ...        ...
# 5131608  -0.300495    0    0  300123134     111.0  -0.315306
# 5131609   0.258936    0    0  300123134     111.0  -0.349366
# 5131610   0.269149    0    0  300123134     111.0  -0.270430
# 5131611  -0.213081    0    0  300123134     111.0  -0.341398
# 5131612   0.416615    0    0  300123134     111.0  -0.289803
#
# [5131613 rows x 13 columns]

# %%
X_train_val, X_test, y_train_val, y_test, labels  = get_features(options, yamlConfig)
# Out:
# C:\Users\jjren\CNN1D\train.py:33: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   h5File = h5py.File(options.inputFile)
# (5131613,)
# ('index', 'j_ptfrac', 'j_pt', 'j_eta', 'j_mass', 'j_tau1_b1', 'j_tau2_b1', 'j_tau3_b1', 'j_tau1_b2', 'j_tau2_b2', 'j_tau3_b2', 'j_tau32_b1', 'j_tau32_b2', 'j_zlogz', 'j_c1_b0', 'j_c1_b1', 'j_c1_b2', 'j_c2_b1', 'j_c2_b2', 'j_d2_b1', 'j_d2_b2', 'j_d2_a1_b1', 'j_d2_a1_b2', 'j_m2_b1', 'j_m2_b2', 'j_n2_b1', 'j_n2_b2', 'j_tau1_b1_mmdt', 'j_tau2_b1_mmdt', 'j_tau3_b1_mmdt', 'j_tau1_b2_mmdt', 'j_tau2_b2_mmdt', 'j_tau3_b2_mmdt', 'j_tau32_b1_mmdt', 'j_tau32_b2_mmdt', 'j_c1_b0_mmdt', 'j_c1_b1_mmdt', 'j_c1_b2_mmdt', 'j_c2_b1_mmdt', 'j_c2_b2_mmdt', 'j_d2_b1_mmdt', 'j_d2_b2_mmdt', 'j_d2_a1_b1_mmdt', 'j_d2_a1_b2_mmdt', 'j_m2_b1_mmdt', 'j_m2_b2_mmdt', 'j_n2_b1_mmdt', 'j_n2_b2_mmdt', 'j_mass_trim', 'j_mass_mmdt', 'j_mass_prun', 'j_mass_sdb2', 'j_mass_sdm1', 'j_multiplicity', 'j1_px', 'j1_py', 'j1_pz', 'j1_e', 'j1_pdgid', 'j1_erel', 'j1_pt', 'j1_ptrel', 'j1_eta', 'j1_etarel', 'j1_etarot', 'j1_phi', 'j1_phirel', 'j1_phirot', 'j1_deltaR', 'j1_costheta', 'j1_costhetarel', 'j1_e1mcosthetarel', 'j_g', 'j_q', 'j_w', 'j_z', 'j_t', 'j_undef', 'j_index')
# (98769, 5)

# %% [markdown]
# # Self-Build Model

# %%
l1Reg = 0.0001

Inputs = Input(shape = (100,7))

x = Conv1D(filters= 8, kernel_size=4, strides=1, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_1',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(Inputs)
x = Conv1D(filters= 4, kernel_size=4, strides=2, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_2',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(x)
x = Conv1D(filters=2, kernel_size=4, strides=3, padding='same',
               kernel_initializer='he_normal', use_bias=True, name='conv1_relu_3',
               activation = 'relu', kernel_regularizer=l1(l1Reg))(x)

x = Flatten()(x)

x = Dense(32, activation='relu', kernel_initializer='lecun_uniform', 
              name='fc1_relu', kernel_regularizer=l1(l1Reg))(x)

predictions = Dense(5, activation='softmax', kernel_initializer='lecun_uniform', name='rnn_densef')(x)
model = Model(inputs=Inputs, outputs=predictions)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 7)]          0
# _________________________________________________________________
# conv1_relu_1 (Conv1D)        (None, 100, 8)            232
# _________________________________________________________________
# conv1_relu_2 (Conv1D)        (None, 50, 4)             132
# _________________________________________________________________
# conv1_relu_3 (Conv1D)        (None, 17, 2)             34
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 34)                0
# _________________________________________________________________
# fc1_relu (Dense)             (None, 32)                1120
# _________________________________________________________________
# rnn_densef (Dense)           (None, 5)                 165
# =================================================================
# Total params: 1,683
# Trainable params: 1,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(lr = 0.0001)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_val, y_train_val, batch_size = 1024, epochs = 100, 
                    validation_split = 0.25, shuffle = True, callbacks = None,
                    use_multiprocessing=True, workers=4)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 1s 25ms/step - loss: 1.6177 - accuracy: 0.2198 - val_loss: 1.5610 - val_accuracy: 0.2641
# Epoch 2/100
# 58/58 [==============================] - 1s 24ms/step - loss: 1.4251 - accuracy: 0.3754 - val_loss: 1.3070 - val_accuracy: 0.4520
# Epoch 3/100
# 58/58 [==============================] - 1s 24ms/step - loss: 1.2372 - accuracy: 0.4942 - val_loss: 1.1662 - val_accuracy: 0.5339
# Epoch 4/100
# 58/58 [==============================] - 1s 24ms/step - loss: 1.1188 - accuracy: 0.5531 - val_loss: 1.0710 - val_accuracy: 0.5710
# Epoch 5/100
# 58/58 [==============================] - 1s 23ms/step - loss: 1.0453 - accuracy: 0.5869 - val_loss: 1.0171 - val_accuracy: 0.5989
# Epoch 6/100
# 58/58 [==============================] - 1s 25ms/step - loss: 1.0010 - accuracy: 0.6054 - val_loss: 0.9821 - val_accuracy: 0.6083
# Epoch 7/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.9749 - accuracy: 0.6182 - val_loss: 0.9626 - val_accuracy: 0.6230
# Epoch 8/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.9577 - accuracy: 0.6272 - val_loss: 0.9492 - val_accuracy: 0.6303
# Epoch 9/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.9441 - accuracy: 0.6348 - val_loss: 0.9357 - val_accuracy: 0.6412
# Epoch 10/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.9334 - accuracy: 0.6423 - val_loss: 0.9268 - val_accuracy: 0.6481
# Epoch 11/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.9230 - accuracy: 0.6501 - val_loss: 0.9172 - val_accuracy: 0.6534
# Epoch 12/100
# 58/58 [==============================] - 2s 29ms/step - loss: 0.9139 - accuracy: 0.6562 - val_loss: 0.9104 - val_accuracy: 0.6616
# Epoch 13/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.9045 - accuracy: 0.6632 - val_loss: 0.9009 - val_accuracy: 0.6671
# Epoch 14/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8961 - accuracy: 0.6679 - val_loss: 0.8903 - val_accuracy: 0.6721
# Epoch 15/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8868 - accuracy: 0.6739 - val_loss: 0.8817 - val_accuracy: 0.6801
# Epoch 16/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8777 - accuracy: 0.6814 - val_loss: 0.8734 - val_accuracy: 0.6831
# Epoch 17/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8694 - accuracy: 0.6869 - val_loss: 0.8645 - val_accuracy: 0.6899
# Epoch 18/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8637 - accuracy: 0.6886 - val_loss: 0.8587 - val_accuracy: 0.6917
# Epoch 19/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8563 - accuracy: 0.6934 - val_loss: 0.8554 - val_accuracy: 0.6963
# Epoch 20/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8514 - accuracy: 0.6960 - val_loss: 0.8489 - val_accuracy: 0.6974
# Epoch 21/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8451 - accuracy: 0.6997 - val_loss: 0.8419 - val_accuracy: 0.7022
# Epoch 22/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8395 - accuracy: 0.7033 - val_loss: 0.8396 - val_accuracy: 0.7022
# Epoch 23/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8361 - accuracy: 0.7039 - val_loss: 0.8401 - val_accuracy: 0.6999
# Epoch 24/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8315 - accuracy: 0.7068 - val_loss: 0.8305 - val_accuracy: 0.7084
# Epoch 25/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8265 - accuracy: 0.7101 - val_loss: 0.8270 - val_accuracy: 0.7092
# Epoch 26/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8239 - accuracy: 0.7106 - val_loss: 0.8219 - val_accuracy: 0.7126
# Epoch 27/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8188 - accuracy: 0.7133 - val_loss: 0.8189 - val_accuracy: 0.7158
# Epoch 28/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8161 - accuracy: 0.7150 - val_loss: 0.8204 - val_accuracy: 0.7120
# Epoch 29/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8134 - accuracy: 0.7153 - val_loss: 0.8121 - val_accuracy: 0.7161
# Epoch 30/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.8093 - accuracy: 0.7183 - val_loss: 0.8116 - val_accuracy: 0.7193
# Epoch 31/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8078 - accuracy: 0.7189 - val_loss: 0.8087 - val_accuracy: 0.7187
# Epoch 32/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8051 - accuracy: 0.7191 - val_loss: 0.8049 - val_accuracy: 0.7198
# Epoch 33/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.8025 - accuracy: 0.7206 - val_loss: 0.8021 - val_accuracy: 0.7206
# Epoch 34/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7998 - accuracy: 0.7222 - val_loss: 0.8027 - val_accuracy: 0.7180
# Epoch 35/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7987 - accuracy: 0.7214 - val_loss: 0.7985 - val_accuracy: 0.7212
# Epoch 36/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7961 - accuracy: 0.7238 - val_loss: 0.7973 - val_accuracy: 0.7212
# Epoch 37/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7946 - accuracy: 0.7243 - val_loss: 0.7948 - val_accuracy: 0.7226
# Epoch 38/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7922 - accuracy: 0.7247 - val_loss: 0.7939 - val_accuracy: 0.7232
# Epoch 39/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7903 - accuracy: 0.7255 - val_loss: 0.7910 - val_accuracy: 0.7250
# Epoch 40/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7889 - accuracy: 0.7264 - val_loss: 0.7918 - val_accuracy: 0.7235
# Epoch 41/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7878 - accuracy: 0.7267 - val_loss: 0.7900 - val_accuracy: 0.7245
# Epoch 42/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7879 - accuracy: 0.7257 - val_loss: 0.7886 - val_accuracy: 0.7241
# Epoch 43/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7848 - accuracy: 0.7272 - val_loss: 0.7897 - val_accuracy: 0.7250
# Epoch 44/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7841 - accuracy: 0.7274 - val_loss: 0.7843 - val_accuracy: 0.7265
# Epoch 45/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7835 - accuracy: 0.7272 - val_loss: 0.7880 - val_accuracy: 0.7260
# Epoch 46/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7813 - accuracy: 0.7280 - val_loss: 0.7822 - val_accuracy: 0.7283
# Epoch 47/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7798 - accuracy: 0.7296 - val_loss: 0.7833 - val_accuracy: 0.7258
# Epoch 48/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7792 - accuracy: 0.7299 - val_loss: 0.7816 - val_accuracy: 0.7279
# Epoch 49/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7787 - accuracy: 0.7299 - val_loss: 0.7855 - val_accuracy: 0.7252
# Epoch 50/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7776 - accuracy: 0.7295 - val_loss: 0.7798 - val_accuracy: 0.7285
# Epoch 51/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7778 - accuracy: 0.7293 - val_loss: 0.7800 - val_accuracy: 0.7290
# Epoch 52/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7758 - accuracy: 0.7307 - val_loss: 0.7812 - val_accuracy: 0.7290
# Epoch 53/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7750 - accuracy: 0.7300 - val_loss: 0.7824 - val_accuracy: 0.7273
# Epoch 54/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7748 - accuracy: 0.7308 - val_loss: 0.7782 - val_accuracy: 0.7300
# Epoch 55/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7733 - accuracy: 0.7317 - val_loss: 0.7771 - val_accuracy: 0.7294
# Epoch 56/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7743 - accuracy: 0.7306 - val_loss: 0.7765 - val_accuracy: 0.7298
# Epoch 57/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7716 - accuracy: 0.7323 - val_loss: 0.7795 - val_accuracy: 0.7276
# Epoch 58/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7731 - accuracy: 0.7309 - val_loss: 0.7797 - val_accuracy: 0.7271
# Epoch 59/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7710 - accuracy: 0.7320 - val_loss: 0.7766 - val_accuracy: 0.7295
# Epoch 60/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7702 - accuracy: 0.7331 - val_loss: 0.7739 - val_accuracy: 0.7314
# Epoch 61/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7694 - accuracy: 0.7334 - val_loss: 0.7748 - val_accuracy: 0.7290
# Epoch 62/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7693 - accuracy: 0.7337 - val_loss: 0.7733 - val_accuracy: 0.7323
# Epoch 63/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7677 - accuracy: 0.7333 - val_loss: 0.7765 - val_accuracy: 0.7304
# Epoch 64/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7678 - accuracy: 0.7341 - val_loss: 0.7726 - val_accuracy: 0.7326
# Epoch 65/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7689 - accuracy: 0.7331 - val_loss: 0.7724 - val_accuracy: 0.7322
# Epoch 66/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7689 - accuracy: 0.7331 - val_loss: 0.7725 - val_accuracy: 0.7316
# Epoch 67/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7672 - accuracy: 0.7331 - val_loss: 0.7772 - val_accuracy: 0.7286
# Epoch 68/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7661 - accuracy: 0.7335 - val_loss: 0.7710 - val_accuracy: 0.7329
# Epoch 69/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7654 - accuracy: 0.7346 - val_loss: 0.7708 - val_accuracy: 0.7330
# Epoch 70/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7658 - accuracy: 0.7345 - val_loss: 0.7696 - val_accuracy: 0.7329
# Epoch 71/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7647 - accuracy: 0.7347 - val_loss: 0.7707 - val_accuracy: 0.7327
# Epoch 72/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7640 - accuracy: 0.7346 - val_loss: 0.7716 - val_accuracy: 0.7309
# Epoch 73/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7638 - accuracy: 0.7341 - val_loss: 0.7706 - val_accuracy: 0.7313
# Epoch 74/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7632 - accuracy: 0.7362 - val_loss: 0.7683 - val_accuracy: 0.7342
# Epoch 75/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7631 - accuracy: 0.7352 - val_loss: 0.7684 - val_accuracy: 0.7334
# Epoch 76/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7649 - accuracy: 0.7336 - val_loss: 0.7693 - val_accuracy: 0.7336
# Epoch 77/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7637 - accuracy: 0.7352 - val_loss: 0.7672 - val_accuracy: 0.7350
# Epoch 78/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7626 - accuracy: 0.7345 - val_loss: 0.7707 - val_accuracy: 0.7313
# Epoch 79/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7624 - accuracy: 0.7359 - val_loss: 0.7717 - val_accuracy: 0.7309
# Epoch 80/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7611 - accuracy: 0.7361 - val_loss: 0.7667 - val_accuracy: 0.7343
# Epoch 81/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7604 - accuracy: 0.7363 - val_loss: 0.7672 - val_accuracy: 0.7332
# Epoch 82/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7602 - accuracy: 0.7364 - val_loss: 0.7707 - val_accuracy: 0.7327
# Epoch 83/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7601 - accuracy: 0.7361 - val_loss: 0.7670 - val_accuracy: 0.7347
# Epoch 84/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7605 - accuracy: 0.7362 - val_loss: 0.7659 - val_accuracy: 0.7353
# Epoch 85/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7609 - accuracy: 0.7363 - val_loss: 0.7676 - val_accuracy: 0.7326
# Epoch 86/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7585 - accuracy: 0.7374 - val_loss: 0.7660 - val_accuracy: 0.7341
# Epoch 87/100
# 58/58 [==============================] - 1s 22ms/step - loss: 0.7590 - accuracy: 0.7364 - val_loss: 0.7712 - val_accuracy: 0.7314
# Epoch 88/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7584 - accuracy: 0.7366 - val_loss: 0.7751 - val_accuracy: 0.7292
# Epoch 89/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7588 - accuracy: 0.7372 - val_loss: 0.7675 - val_accuracy: 0.7330
# Epoch 90/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7576 - accuracy: 0.7377 - val_loss: 0.7640 - val_accuracy: 0.7344
# Epoch 91/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7567 - accuracy: 0.7370 - val_loss: 0.7672 - val_accuracy: 0.7317
# Epoch 92/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7573 - accuracy: 0.7374 - val_loss: 0.7712 - val_accuracy: 0.7306
# Epoch 93/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7568 - accuracy: 0.7375 - val_loss: 0.7637 - val_accuracy: 0.7339
# Epoch 94/100
# 58/58 [==============================] - 1s 23ms/step - loss: 0.7556 - accuracy: 0.7392 - val_loss: 0.7668 - val_accuracy: 0.7332
# Epoch 95/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7562 - accuracy: 0.7380 - val_loss: 0.7625 - val_accuracy: 0.7360
# Epoch 96/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7551 - accuracy: 0.7386 - val_loss: 0.7635 - val_accuracy: 0.7354
# Epoch 97/100
# 58/58 [==============================] - 1s 26ms/step - loss: 0.7562 - accuracy: 0.7382 - val_loss: 0.7654 - val_accuracy: 0.7345
# Epoch 98/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7546 - accuracy: 0.7391 - val_loss: 0.7642 - val_accuracy: 0.7346
# Epoch 99/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.7548 - accuracy: 0.7390 - val_loss: 0.7620 - val_accuracy: 0.7366
# Epoch 100/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7537 - accuracy: 0.7392 - val_loss: 0.7611 - val_accuracy: 0.7367

# %% [markdown]
# # Conv1d Evaluation

# %%
def learningCurve(history):
    plt.figure(figsize=(10,8))
    plt.plot(history.history['loss'], linewidth=1)
    plt.plot(history.history['val_loss'], linewidth=1)
    plt.title('Model Loss over Epochs')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['training sample loss','validation sample loss'])
    plt.savefig('Learning_curve.pdf')
    plt.show()
    plt.close()

learningCurve(history)

# %%
def makeRoc(features_val, labels_val, labels, model, outputDir='', outputSuffix=''):
    from sklearn.metrics import roc_curve, auc
    labels_pred = model.predict(features_val)
    df = pd.DataFrame()
    fpr = {}
    tpr = {}
    auc1 = {}
    plt.figure(figsize=(10,8))
    for i, label in enumerate(labels):
        df[label] = labels_val[:,i]
        df[label + '_pred'] = labels_pred[:,i]
        fpr[label], tpr[label], threshold = roc_curve(df[label],df[label+'_pred'])
        auc1[label] = auc(fpr[label], tpr[label])
        plt.plot(fpr[label],tpr[label],label='%s tagger, AUC = %.1f%%'%(label.replace('j_',''),auc1[label]*100.))
    plt.plot([0, 1], [0, 1], lw=1, color='black', linestyle='--')
    #plt.semilogy()
    plt.xlabel("Background Efficiency")
    plt.ylabel("Signal Efficiency")
    plt.xlim([-0.05, 1.05])
    plt.ylim(0.001,1.05)
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.figtext(0.25, 0.90,'Conv1d ROC Curve',fontweight='bold', wrap=True, horizontalalignment='right', fontsize=14)
    #plt.figtext(0.35, 0.90,'preliminary', style='italic', wrap=True, horizontalalignment='center', fontsize=14) 
    #plt.savefig('%sROC_%s.pdf'%(outputDir, outputSuffix))
    return labels_pred

y_pred = makeRoc(X_test, y_test, labels, model, outputSuffix='conv1d')

# %%
if 'j_index' in labels: labels.remove('j_index')

predict_test = model.predict(X_test)

df = pd.DataFrame()

fpr = {}
tpr = {}
auc1 = {}

plt.figure()       
for i, label in enumerate(labels):
    df[label] = y_test[:,i]
    df[label + '_pred'] = predict_test[:,i]

    fpr[label], tpr[label], threshold = roc_curve(df[label],df[label+'_pred'])

    auc1[label] = auc(fpr[label], tpr[label])

    plt.plot(tpr[label],fpr[label],label='%s tagger, AUC = %.1f%%'%(label.replace('j_',''),auc1[label]*100.))
plt.semilogy()
plt.xlabel("Signal Efficiency")
plt.ylabel("Background Efficiency")
plt.ylim(0.001,1)
plt.grid(True)
plt.legend(loc='upper left')
plt.figtext(0.25, 0.90,'Conv_1d_ROC',fontweight='bold', wrap=True, horizontalalignment='right', fontsize=14)
# Out:
# Text(0.25, 0.9, 'Conv_1d_ROC')
