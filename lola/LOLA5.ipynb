# %%
import utils
import classes
import h5py
import pandas as pd
from keras.layers import *
from keras import Model
from keras.models import Sequential
from keras.layers.advanced_activations import PReLU
from keras import regularizers
import numpy as np
import keras, time
import keras.backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
nConstituents=40

# %%
features = np.load('loladata/lolofeaturesreshape.npy')
labels = np.load('loladata/lolalabel.npy')

# %%
features.shape
# Out:
# (98769, 4, 40)

# %%
labels.shape
# Out:
# (98769, 5)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
model = classes.LoLaClassifier(nConstituents=40, nAdded=10).model

# %%
model.compile(
        optimizer=keras.optimizers.Adam(lr=0.0001), 
        loss='categorical_crossentropy', 
        metrics=['acc'])

# %%
    print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 4, 40)             0
# _________________________________________________________________
# cola (CoLa)                  (None, 4, 50)             400
# _________________________________________________________________
# lola (LoLa)                  (None, 7, 50)             2704
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 350)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               35100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# ...

# %%
history = model.fit(X_train, y_train,
        verbose=2,
        batch_size=1024,
        validation_split=0.2,
        epochs=200)
# Out:
# Train on 63212 samples, validate on 15803 samples
# Epoch 1/200
#  - 1s - loss: 3.6525 - acc: 0.2807 - val_loss: 1.8010 - val_acc: 0.2670
# Epoch 2/200
#  - 1s - loss: 1.6790 - acc: 0.2736 - val_loss: 1.6060 - val_acc: 0.2898
# Epoch 3/200
#  - 1s - loss: 1.5804 - acc: 0.3025 - val_loss: 1.5577 - val_acc: 0.3188
# Epoch 4/200
#  - 1s - loss: 1.5452 - acc: 0.3273 - val_loss: 1.5341 - val_acc: 0.3357
# Epoch 5/200
#  - 1s - loss: 1.5209 - acc: 0.3453 - val_loss: 1.5168 - val_acc: 0.3557
# Epoch 6/200
#  - 1s - loss: 1.5003 - acc: 0.3654 - val_loss: 1.4988 - val_acc: 0.3693
# Epoch 7/200
#  - 1s - loss: 1.4815 - acc: 0.3794 - val_loss: 1.4843 - val_acc: 0.3752
# Epoch 8/200
#  - 1s - loss: 1.4654 - acc: 0.3887 - val_loss: 1.4738 - val_acc: 0.3883
# Epoch 9/200
#  - 1s - loss: 1.4504 - acc: 0.3981 - val_loss: 1.4631 - val_acc: 0.4007
# Epoch 10/200
#  - 1s - loss: 1.4371 - acc: 0.4116 - val_loss: 1.4519 - val_acc: 0.4150
# Epoch 11/200
# ...

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training set','validation set'])
plt.show()

# %%
label = ['j_g','j_q','j_w','j_z','j_t']

def makeRoc(features_val, labels_val, labels, model, outputDir='', outputSuffix=''):
    from sklearn.metrics import roc_curve, auc
    labels_pred = model.predict(features_val)
    df = pd.DataFrame()
    fpr = {}
    tpr = {}
    auc1 = {}
    plt.figure(figsize=(10,8))
    for i, label in enumerate(labels):
        df[label] = labels_val[:,i]
        df[label + '_pred'] = labels_pred[:,i]
        fpr[label], tpr[label], threshold = roc_curve(df[label],df[label+'_pred'])
        auc1[label] = auc(fpr[label], tpr[label])
        plt.plot(fpr[label],tpr[label],label='%s tagger, AUC = %.1f%%'%(label.replace('j_',''),auc1[label]*100.))
    plt.plot([0, 1], [0, 1], lw=1, color='black', linestyle='--')
    #plt.semilogy()
    plt.xlabel("Background Efficiency")
    plt.ylabel("Signal Efficiency")
    plt.xlim([-0.05, 1.05])
    plt.ylim(0.001,1.05)
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.figtext(0.25, 0.90,'LOLA ROC Curve',fontweight='bold', wrap=True, horizontalalignment='right', fontsize=14)
    #plt.figtext(0.35, 0.90,'preliminary', style='italic', wrap=True, horizontalalignment='center', fontsize=14) 
    #plt.savefig('%sROC_%s.pdf'%(outputDir, outputSuffix))
    return labels_pred

# %%
y_pred = makeRoc(X_test, y_test, label, model, outputSuffix='LOLA5')
